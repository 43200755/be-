# %% [markdown]
# <a href="https://colab.research.google.com/github/43200755/be-/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
caro=pd.read_csv('/content/caro.csv',names=['Car_Name','Year','Selling_Price','Present_Price','Kms_Driven'])
caro.head()
# Out:
#                                              Car_Name       Year  \
# Car_Name Year Selling_Price Present_Price  Kms_Driven  Fuel_Type
# ritz     2014 3.35          5.59                27000     Petrol
# sx4      2013 4.75          9.54                43000     Diesel
# ciaz     2017 7.25          9.85                 6900     Petrol
# wagon r  2011 2.85          4.15                 5200     Petrol
#
#                                           Selling_Price Present_Price  \
# Car_Name Year Selling_Price Present_Price   Seller_Type  Transmission
# ritz     2014 3.35          5.59                 Dealer        Manual
# sx4      2013 4.75          9.54                 Dealer        Manual
# ciaz     2017 7.25          9.85                 Dealer        Manual
# wagon r  2011 2.85          4.15                 Dealer        Manual
#
#                                           Kms_Driven
# Car_Name Year Selling_Price Present_Price      Owner
# ...

# %%
import matplotlib.pyplot as plt
x=caro['Selling_Price']
y=caro['Present_Price']
plt.scatter(x,y)
plt.title("Scatter plot Selling_Price vs Year")
plt.xlabel("Selling_Price")
plt.ylabel("Present_Price")
# Out:
# Text(0, 0.5, 'Present_Price')
